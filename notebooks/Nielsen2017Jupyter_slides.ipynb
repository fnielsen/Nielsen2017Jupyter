# %% [markdown]
# # Slideshow
# Finn Årup Nielsen

# %% [markdown]
# ## First slide with import of
#
# - Numpy
# - SciPy
# - Matplotlib

# %%
import numpy as np
import scipy
import matplotlib.pyplot as plt

# %% [markdown]
# ## Some computations

# %%
x = np.linspace(0, 8)
y = np.sin(x)
plt.plot(x, y)
plt.show()
